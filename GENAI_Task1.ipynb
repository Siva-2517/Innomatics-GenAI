# %%
from langchain_core.prompts import PromptTemplate

# reusable template
basic_template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} in simple terms for beginners"
)

def explain_topic(topic):
    return basic_template.format(topic=topic)

# test
print(explain_topic("AI"))
# Out:
# Explain AI in simple terms for beginners

# %%
multi_template = PromptTemplate(
    input_variables=["topic", "audience", "tone"],
    template="Explain {topic} for {audience} in a {tone} tone"
)

def generate_multi_prompt(topic, audience, tone):
    return multi_template.format(
        topic=topic,
        audience=audience,
        tone=tone
    )

# test cases
print(generate_multi_prompt("AI", "beginners", "friendly"))
print(generate_multi_prompt("Python", "kids", "fun"))
print(generate_multi_prompt("Deep Learning", "engineers", "technical"))
# Out:
# Explain AI for beginners in a friendly tone
# Explain Python for kids in a fun tone
# Explain Deep Learning for engineers in a technical tone

# %%
# Teaching
teaching_template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} clearly step by step"
)

# Interview
interview_template = PromptTemplate(
    input_variables=["topic"],
    template="Ask 3 interview questions about {topic}"
)

# Storytelling
story_template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} as a story"
)

topic = "Machine Learning"

print(teaching_template.format(topic=topic))
print(interview_template.format(topic=topic))
print(story_template.format(topic=topic))
# Out:
# Explain Machine Learning clearly step by step
# Ask 3 interview questions about Machine Learning
# Explain Machine Learning as a story

# %%
from langchain_core.prompts import ChatPromptTemplate

def build_chat_prompt(role, topic):

    if role == "teacher":
        system_msg = "You are a helpful teacher who explains concepts simply."
    elif role == "interviewer":
        system_msg = "You are an interviewer asking challenging questions."
    elif role == "motivator":
        system_msg = "You are a motivational speaker who inspires learning."
    else:
        system_msg = "You are a helpful assistant."

    chat_template = ChatPromptTemplate.from_messages([
        ("system", system_msg),
        ("user", "Talk about {topic}")
    ])

    return chat_template.format_messages(topic=topic)

# test
messages = build_chat_prompt("teacher", "Neural Networks")
print(messages)
# Out:
# [SystemMessage(content='You are a helpful teacher who explains concepts simply.', additional_kwargs={}, response_metadata={}), HumanMessage(content='Talk about Neural Networks', additional_kwargs={}, response_metadata={})]

# %%
def validate_inputs(audience, tone):
    valid_audience = ["beginner", "intermediate", "expert"]
    valid_tone = ["formal", "casual", "fun"]

    if audience not in valid_audience:
        print("Invalid audience. Setting default = beginner")
        audience = "beginner"

    if tone not in valid_tone:
        print("Invalid tone. Setting default = formal")
        tone = "formal"

    return audience, tone

# test
print(validate_inputs("kids", "cool"))
# Out:
# Invalid audience. Setting default = beginner
# Invalid tone. Setting default = formal
# ('beginner', 'formal')

# %%
def generate_prompt(topic, audience, tone, style):

    # validate first
    audience, tone = validate_inputs(audience, tone)

    if style == "teaching":
        template = PromptTemplate(
            input_variables=["topic", "audience", "tone"],
            template="Teach {topic} to {audience} in a {tone} way step by step"
        )

    elif style == "interview":
        template = PromptTemplate(
            input_variables=["topic", "audience", "tone"],
            template="Ask interview questions about {topic} for {audience} in a {tone} tone"
        )

    elif style == "storytelling":
        template = PromptTemplate(
            input_variables=["topic", "audience", "tone"],
            template="Explain {topic} for {audience} in a {tone} storytelling style"
        )

    else:
        return "Invalid style selected"

    return template.format(
        topic=topic,
        audience=audience,
        tone=tone
    )

# test
print(generate_prompt("Neural Networks", "beginner", "fun", "storytelling"))
# Out:
# Explain Neural Networks for beginner in a fun storytelling style

# %%
reusable_template = PromptTemplate(
    input_variables=["topic"],
    template="Give a simple explanation of {topic}"
)

topics = ["AI", "Python", "DBMS", "OS", "Computer Networks"]

for t in topics:
    print(reusable_template.format(topic=t))
# Out:
# Give a simple explanation of AI
# Give a simple explanation of Python
# Give a simple explanation of DBMS
# Give a simple explanation of OS
# Give a simple explanation of Computer Networks
